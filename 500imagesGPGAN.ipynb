# %%
# !git clone https://github.com/MiaoyunZhao/GANTransferLimitedData.git
# Out:
# Cloning into 'GANTransferLimitedData'...
# remote: Enumerating objects: 211, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 211 (delta 38), reused 3 (delta 0), pack-reused 141
# Receiving objects: 100% (211/211), 8.66 MiB | 13.02 MiB/s, done.
# Resolving deltas: 100% (106/106), done.

# %%
cd GANTransferLimitedData/
# Out:
# /home/jovyan/git-repos/GANTransferLimitedData

# %%
# !python download_pretrainedGAN.py
# Out:
# /home/jovyan/git-repos/GANTransferLimitedData/gan_training/config.py:18: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg_special = yaml.load(f)
# /home/jovyan/git-repos/GANTransferLimitedData/gan_training/config.py:29: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(f)
# Generator(
#   (embedding): Embedding(1000, 256)
#   (fc): Linear(in_features=512, out_features=16384, bias=True)
#   (resnet_0_0): ResnetBlock(
#     (conv_0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_0_1): ResnetBlock(
#     (conv_0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_1_0): ResnetBlock(
#     (conv_0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_1_1): ResnetBlock(
#     (conv_0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_2_0): ResnetBlock(
#     (conv_0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_s): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (resnet_2_1): ResnetBlock(
#     (conv_0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_3_0): ResnetBlock(
#     (conv_0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_s): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (resnet_3_1): ResnetBlock(
#     (conv_0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_4_0): ResnetBlock(
#     (conv_0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_s): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (resnet_4_1): ResnetBlock(
#     (conv_0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_5_0): ResnetBlock(
#     (conv_0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_s): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (resnet_5_1): ResnetBlock(
#     (conv_0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv_img): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# Discriminator(
#   (conv_img): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resnet_0_0): ResnetBlock(
#     (conv_0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_0_1): ResnetBlock(
#     (conv_0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_s): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (resnet_1_0): ResnetBlock(
#     (conv_0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_1_1): ResnetBlock(
#     (conv_0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_s): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (resnet_2_0): ResnetBlock(
#     (conv_0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_2_1): ResnetBlock(
#     (conv_0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_s): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (resnet_3_0): ResnetBlock(
#     (conv_0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_3_1): ResnetBlock(
#     (conv_0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_s): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (resnet_4_0): ResnetBlock(
#     (conv_0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_4_1): ResnetBlock(
#     (conv_0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_5_0): ResnetBlock(
#     (conv_0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resnet_5_1): ResnetBlock(
#     (conv_0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (fc): Linear(in_features=16384, out_features=1000, bias=True)
# )
# tensor([[-2.3873e-03,  7.7929e-03,  7.8849e-03],
#         [-4.3784e-03, -8.9464e-03,  1.0383e-04],
#         [ 1.0963e-03,  6.0049e-05,  6.0256e-04]], device='cuda:0',
#        grad_fn=<SliceBackward>)
# https://s3.eu-central-1.amazonaws.com/avg-projects/gan_stability/models/imagenet-8c505f47.pt
# => Loading checkpoint from url...
# tensor([[ 0.1460,  0.0110, -0.0497],
#         [ 0.0074,  0.0181, -0.0525],
#         [ 0.0588, -0.0327,  0.0424]], device='cuda:0', grad_fn=<SliceBackward>)

# %%
# !ls
# Out:
# 'CELEBA_[f]GmDn.py'	     F:			 LICENSE
#  configs		    'Flower_[h]our.py'	 pretained_model
#  data			     Flowers25_our.py	 README.md
#  download_pretrainedGAN.py   gan_training	 TransferGANLimitedData_v4.pdf

# %%
import torch
print(torch.__Version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_166/368891291.py in <module>
#       1 import torch
# ----> 2 print(torch.__Version__)
#
# AttributeError: module 'torch' has no attribute '__Version__'

# %%
import argparse
import os, sys
from os import path
import time
import copy
import torch
from torch import nn
import numpy as np
import random
# from torchsummary import summary
import shutil
import scipy.io as sio


def seed_torch(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True


seed_torch(999)


from gan_training import utils
from gan_training.train import Trainer, update_average
from gan_training.toggle_ImageNet import toggle_grad_G, toggle_grad_D
from gan_training.logger import Logger
from gan_training.checkpoints import CheckpointIO
from gan_training.inputs import get_dataset
from gan_training.distributions import get_ydist, get_zdist
from gan_training.eval import Evaluator
from gan_training.config import (
    load_config, build_models, build_optimizers, build_lr_scheduler, build_models_PRE,
)


def my_embedding(z, y, nlabels=1):
    e_y=torch.zeros(y.shape[0], nlabels,device=y.device).scatter_(1, (y).unsqueeze(1), 1)
    # print('e_y.shape===============', e_y.shape)
    output = z * e_y
    return output


def get_parameter_number(net):
    total_num = sum(p.numel() for p in net.parameters())
    trainable_num = sum(p.numel() for p in net.parameters() if p.requires_grad)
    print('Total=', total_num, 'Trainable=', trainable_num, 'fixed=', total_num-trainable_num)


def load_part_model(m_fix, m_ini):
    dict_fix = m_fix.state_dic()
    dict_ini = m_ini.state_dic()

    dict_fix = {k: v for k, v in dict_fix.items() if k in dict_ini and k.find('embedding')==-1 and k.find('fc') == -1}
    dict_ini.update(dict_fix)
    m_ini.load_state_dict(dict_ini)
    return m_ini


def model_equal_all(model, dict):
    model_dict = model.state_dict()
    model_dict.update(dict)
    model.load_state_dict(model_dict)
    return model


def model_equal_part(model, dict_all):
    model_dict = model.state_dict()
    dict_fix = {k: v for k, v in dict_all.items() if k in model_dict and k.find('embedding') == -1 and k.find('fc') == -1}
    model_dict.update(dict_fix)
    model.load_state_dict(model_dict)
    return model


''' ===================--- Set the traning mode ---==========================
DATA: going to train
DATA_FIX: used as a fixed pre-trained model
G_Layer_FIX, D_Layer_FIX: number of layers to fix
============================================================================='''
DATA_FIX = 'ImageNet'
Num_epoch = 5000 *10000
method = 'AdaFM' # scratch

main_path = './'
load_dir = './pretrained_model/'


DATA = 'textures'
image_path = 'data/originals/'
test_path = 'data/originals/'


out_path = main_path+'/'+DATA+'_our_contral_kernel_25_v2_16z_10reg/'
config_path = 'configs/' +DATA+ '.yaml'


for choose in range(1):

    G_Layer_FIX = -4
    D_Layer_FIX = 6

    config = load_config(config_path, 'configs/default.yaml')

    config['generator']['layers'] = G_Layer_FIX
    config['discriminator']['layers'] = D_Layer_FIX
    config['data']['train_dir'] = image_path
    config['data']['test_dir'] = test_path
    config['z_dist']['dim'] = 4
    config['training']['reg_type'] = 'real_fake'
    config['training']['reg_param'] = 20.0
    config['training']['batch_size'] = 16

    config['generator']['name'] = 'resnet2_AdaFM'
    config['discriminator']['name'] = 'resnet2_AdaFM'

    config['training']['out_dir'] = out_path + 'G_%d_D_%d/'%(-G_Layer_FIX, D_Layer_FIX)
    if not os.path.isdir(config['training']['out_dir']):
        os.makedirs(config['training']['out_dir'])

    if 1:
        # Short hands
        batch_size = config['training']['batch_size']
        d_steps = config['training']['d_steps']
        restart_every = config['training']['restart_every']
        inception_every = config['training']['inception_every']
        save_every = config['training']['save_every']
        backup_every = config['training']['backup_every']
        sample_nlabels = config['training']['sample_nlabels']

        out_dir = config['training']['out_dir']
        checkpoint_dir = path.join(out_dir, 'chkpts')

        # Create missing directories
        if not path.exists(out_dir):
            os.makedirs(out_dir)
        if not path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        shutil.copyfile(sys.argv[0], out_dir + '/training_script.py')

        # Logger
        checkpoint_io = CheckpointIO(
            checkpoint_dir=checkpoint_dir
        )

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # Dataset
        train_dataset, nlabels = get_dataset(
            name=config['data']['type'],
            data_dir=config['data']['train_dir'],
            size=config['data']['img_size'],
            lsun_categories=config['data']['lsun_categories_train']
        )
        train_loader = torch.utils.data.DataLoader(
                train_dataset,
                batch_size=batch_size,
                num_workers=config['training']['nworkers'],
                shuffle=True, pin_memory=True, sampler=None, drop_last=True
        )
        test_dataset, nlabels = get_dataset(
            name=config['data']['type'],
            data_dir=config['data']['test_dir'],
            size=config['data']['img_size'],
            lsun_categories=config['data']['lsun_categories_train']
        )
        test_loader = torch.utils.data.DataLoader(
            test_dataset,
            batch_size=batch_size,
            num_workers=config['training']['nworkers'],
            shuffle=True, pin_memory=True, sampler=None, drop_last=True
        )

        # Number of labels
        nlabels = min(nlabels, config['data']['nlabels'])
        sample_nlabels = min(nlabels, sample_nlabels)





        # Create models
        ''' --------- Choose the fixed layer ---------------'''
        generator, discriminator = build_models(config)

        if method == 'AdaFM':
            dict_G = torch.load(load_dir + DATA_FIX + 'Pre_generator')
            generator = model_equal_part(generator, dict_G)
            dict_D = torch.load(load_dir + DATA_FIX + 'Pre_discriminator')
            discriminator = model_equal_part(discriminator, dict_D)

            for name, param in generator.named_parameters():
                if name.find('small') >= 0:
                    param.requires_grad = True
                else:
                    param.requires_grad = False
                if name.find('small_adafm_') >= 0:
                    param.requires_grad = False
            get_parameter_number(generator)

            for param in discriminator.parameters():
                param.requires_grad = False

            #toggle_grad_G(generator, True, G_Layer_FIX)
            toggle_grad_D(discriminator, True, D_Layer_FIX)





        # Put models on gpu if needed
        generator, discriminator = generator.to(device), discriminator.to(device)
        g_optimizer, d_optimizer = build_optimizers(generator, discriminator, config)


        # Register modules to checkpoint
        checkpoint_io.register_modules(
            generator=generator,
            discriminator=discriminator,
            g_optimizer=g_optimizer,
            d_optimizer=d_optimizer,
        )


        # Logger
        logger = Logger(
            log_dir=path.join(out_dir, 'logs'),
            img_dir=path.join(out_dir, 'imgs'),
            monitoring=config['training']['monitoring'],
            monitoring_dir=path.join(out_dir, 'monitoring')
        )

        # Distributions
        ydist = get_ydist(1, device=device)
        zdist = get_zdist(config['z_dist']['type'], config['z_dist']['dim'],
                          device=device)

        # Save for tests
        ntest = 16
        x_real, ytest = utils.get_nsamples(train_loader, ntest)
        ytest.clamp_(None, nlabels-1)
        ytest = ytest.to(device)
        ztest = zdist.sample((ntest,)).to(device)
        # utils.save_images(x_real, path.join(out_dir, 'real.png'))

        # Test generator
        if config['training']['take_model_average']:
            generator_test = copy.deepcopy(generator)
            checkpoint_io.register_modules(generator_test=generator_test)
        else:
            generator_test = generator

        # Evaluator

        NNN = 251
        x_real, _ = utils.get_nsamples(test_loader, NNN)
        evaluator = Evaluator(generator_test, zdist, ydist,
                              batch_size=batch_size, device=device,
                              fid_real_samples=x_real, inception_nsamples=NNN, fid_sample_size=NNN)
        # Train
        tstart = t0 = time.time()


        it = -1
        epoch_idx = -1

        # Reinitialize model average if needed
        if (config['training']['take_model_average']
                and config['training']['model_average_reinit']):
            update_average(generator_test, generator, 0.)

        # Learning rate anneling
        g_scheduler = build_lr_scheduler(g_optimizer, config, last_epoch=it)
        d_scheduler = build_lr_scheduler(d_optimizer, config, last_epoch=it)

        # Trainer
        trainer = Trainer(
            generator, discriminator, g_optimizer, d_optimizer,
            gan_type=config['training']['gan_type'],
            reg_type=config['training']['reg_type'],
            reg_param=config['training']['reg_param'],
            D_fix_layer=config['discriminator']['layers']
        )


    # Training loop
    print('Start training...')
    save_dir = config['training']['out_dir'] + '/models/'
    if not os.path.isdir(save_dir):
        os.makedirs(save_dir)
    FLAG = 500

    inception_mean_all = []
    inception_std_all = []
    fid_all = []
    get_parameter_number(generator)
    get_parameter_number(discriminator)

    for epoch_idx in range(Num_epoch):

        for x_real, y in train_loader:
            it += 1
            g_scheduler.step()
            d_scheduler.step()

            d_lr = d_optimizer.param_groups[0]['lr']
            g_lr = g_optimizer.param_groups[0]['lr']

            x_real, y = x_real.to(device), y.to(device)
            y.clamp_(None, nlabels-1)

            # Generators updates
            z = zdist.sample((batch_size,)).to(device)

            gloss, x_fake = trainer.generator_trainstep(y, z, FLAG + 1.0)
            FLAG = FLAG * 0.9995

            if config['training']['take_model_average']:
                update_average(generator_test, generator,
                               beta=config['training']['model_average_beta'])

            # Discriminator updates
            dloss, reg = trainer.discriminator_trainstep(x_real, y, x_fake)

            if method == 'AdaFM' and it == 10000:
                for name, param in generator.named_parameters():
                    if name.find('small_adafm_') >= 0:
                        param.requires_grad = True
                get_parameter_number(generator)

            with torch.no_grad():
                # (i) Sample if necessary
                if (it % 100) == 0:
                    d_fix, d_update = discriminator.conv_img.weight[1, 1, 1, 1], discriminator.fc.weight[0, 1]
                    g_fix, g_update = generator.conv_img.weight[1, 1, 1, 1], 0.0

                    print('[epoch %0d, it %4d] g_loss = %.4f, d_loss = %.4f, reg=%.4f, d_fix=%.4f, d_update=%.4f, g_fix=%.4f, g_update=%.4f'
                          % (epoch_idx, it, gloss, dloss, reg, d_fix, d_update, g_fix, g_update))
                    # print('Creating samples...')
                    x, _ = generator_test(ztest, ytest)
                    logger.add_imgs(x, 'all', it, nrow=10)

                # (ii) Compute inception if necessary
                if ((it + 2) % 5000) == 0:
                    inception_mean, inception_std, fid = evaluator.compute_inception_score()
                    inception_mean_all.append(inception_mean)
                    inception_std_all.append(inception_std)
                    fid_all.append(fid)
                    print('test it %d: IS: mean %.2f, std %.2f, FID: mean %.2f, time: %2f' % (
                        it, inception_mean, inception_std, fid, time.time() - tstart))

                    FID = np.stack(fid_all)
                    Inception_mean = np.stack(inception_mean_all)
                    Inception_std = np.stack(inception_std_all)
                    sio.savemat(out_path + DATA + 'base_FID_IS.mat', {'FID': FID,
                                                           'Inception_mean': Inception_mean,
                                                           'Inception_std': Inception_std})

                # (iii) Backup if necessary
                if ((it + 1) % backup_every) == 0:
                    print('Saving backup...')
                    checkpoint_io.save('model_%08d.pt' % it, it=it)
# Out:
# /home/jovyan/git-repos/GANTransferLimitedData/gan_training/config.py:18: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg_special = yaml.load(f)
# /home/jovyan/git-repos/GANTransferLimitedData/gan_training/config.py:29: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(f)
# nlabels ============  1
# Total= 27963332 Trainable= 23056897 fixed= 4906435
# Start training...
# Total= 27963332 Trainable= 23056897 fixed= 4906435
# Total= 91892161 Trainable= 37769217 fixed= 54122944
# /srv/conda/envs/saturn/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:129: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# [epoch 0, it    0] g_loss = 0.6946, d_loss = 1.3872, reg=0.0000, d_fix=-0.0469, d_update=-0.0026, g_fix=-0.0001, g_update=0.0000
# [epoch 3, it  100] g_loss = 0.7911, d_loss = 1.2589, reg=0.0160, d_fix=-0.0469, d_update=-0.0027, g_fix=-0.0001, g_update=0.0000
# [epoch 6, it  200] g_loss = 0.7694, d_loss = 1.2077, reg=0.0162, d_fix=-0.0469, d_update=-0.0026, g_fix=-0.0001, g_update=0.0000
# [epoch 9, it  300] g_loss = 0.6713, d_loss = 1.2395, reg=0.0327, d_fix=-0.0469, d_update=-0.0031, g_fix=-0.0001, g_update=0.0000
# [epoch 12, it  400] g_loss = 1.1901, d_loss = 1.3711, reg=0.0575, d_fix=-0.0469, d_update=-0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 16, it  500] g_loss = 0.6144, d_loss = 1.2477, reg=0.0217, d_fix=-0.0469, d_update=-0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 19, it  600] g_loss = 0.8573, d_loss = 1.1879, reg=0.0154, d_fix=-0.0469, d_update=-0.0027, g_fix=-0.0001, g_update=0.0000
# [epoch 22, it  700] g_loss = 0.6436, d_loss = 1.2879, reg=0.0215, d_fix=-0.0469, d_update=-0.0023, g_fix=-0.0001, g_update=0.0000
# [epoch 25, it  800] g_loss = 1.0569, d_loss = 1.2651, reg=0.0154, d_fix=-0.0469, d_update=-0.0019, g_fix=-0.0001, g_update=0.0000
# [epoch 29, it  900] g_loss = 1.1635, d_loss = 1.2483, reg=0.0255, d_fix=-0.0469, d_update=-0.0016, g_fix=-0.0001, g_update=0.0000
# [epoch 32, it 1000] g_loss = 0.8484, d_loss = 1.1722, reg=0.0308, d_fix=-0.0469, d_update=-0.0015, g_fix=-0.0001, g_update=0.0000
# [epoch 35, it 1100] g_loss = 1.0935, d_loss = 1.2151, reg=0.0353, d_fix=-0.0469, d_update=-0.0012, g_fix=-0.0001, g_update=0.0000
# [epoch 38, it 1200] g_loss = 1.3251, d_loss = 1.2921, reg=0.0367, d_fix=-0.0469, d_update=-0.0012, g_fix=-0.0001, g_update=0.0000
# [epoch 41, it 1300] g_loss = 0.9678, d_loss = 1.2433, reg=0.0311, d_fix=-0.0469, d_update=-0.0008, g_fix=-0.0001, g_update=0.0000
# [epoch 45, it 1400] g_loss = 0.9826, d_loss = 1.1998, reg=0.0304, d_fix=-0.0469, d_update=-0.0017, g_fix=-0.0001, g_update=0.0000
# [epoch 48, it 1500] g_loss = 0.4427, d_loss = 1.3746, reg=0.0360, d_fix=-0.0469, d_update=-0.0022, g_fix=-0.0001, g_update=0.0000
# [epoch 51, it 1600] g_loss = 1.1070, d_loss = 1.2669, reg=0.0279, d_fix=-0.0469, d_update=-0.0015, g_fix=-0.0001, g_update=0.0000
# [epoch 54, it 1700] g_loss = 0.8492, d_loss = 1.0798, reg=0.0442, d_fix=-0.0469, d_update=-0.0021, g_fix=-0.0001, g_update=0.0000
# [epoch 58, it 1800] g_loss = 0.9288, d_loss = 1.1790, reg=0.0352, d_fix=-0.0469, d_update=-0.0015, g_fix=-0.0001, g_update=0.0000
# [epoch 61, it 1900] g_loss = 0.6798, d_loss = 1.0961, reg=0.0403, d_fix=-0.0469, d_update=-0.0014, g_fix=-0.0001, g_update=0.0000
# [epoch 64, it 2000] g_loss = 1.3066, d_loss = 1.2787, reg=0.0516, d_fix=-0.0469, d_update=-0.0009, g_fix=-0.0001, g_update=0.0000
# [epoch 67, it 2100] g_loss = 1.0049, d_loss = 1.0264, reg=0.0439, d_fix=-0.0469, d_update=-0.0007, g_fix=-0.0001, g_update=0.0000
# [epoch 70, it 2200] g_loss = 1.1025, d_loss = 1.0686, reg=0.0397, d_fix=-0.0469, d_update=-0.0002, g_fix=-0.0001, g_update=0.0000
# [epoch 74, it 2300] g_loss = 1.3185, d_loss = 1.2040, reg=0.0452, d_fix=-0.0469, d_update=-0.0007, g_fix=-0.0001, g_update=0.0000
# [epoch 77, it 2400] g_loss = 0.9779, d_loss = 1.1340, reg=0.0459, d_fix=-0.0469, d_update=-0.0012, g_fix=-0.0001, g_update=0.0000
# [epoch 80, it 2500] g_loss = 0.7122, d_loss = 1.1158, reg=0.0451, d_fix=-0.0469, d_update=-0.0010, g_fix=-0.0001, g_update=0.0000
# [epoch 83, it 2600] g_loss = 0.6418, d_loss = 1.0731, reg=0.0508, d_fix=-0.0469, d_update=-0.0019, g_fix=-0.0001, g_update=0.0000
# [epoch 87, it 2700] g_loss = 1.2886, d_loss = 1.1574, reg=0.0474, d_fix=-0.0469, d_update=-0.0011, g_fix=-0.0001, g_update=0.0000
# [epoch 90, it 2800] g_loss = 1.0392, d_loss = 1.1046, reg=0.0506, d_fix=-0.0469, d_update=-0.0011, g_fix=-0.0001, g_update=0.0000
# [epoch 93, it 2900] g_loss = 1.1192, d_loss = 0.8907, reg=0.0609, d_fix=-0.0469, d_update=-0.0013, g_fix=-0.0001, g_update=0.0000
# [epoch 96, it 3000] g_loss = 0.9961, d_loss = 0.8516, reg=0.0552, d_fix=-0.0469, d_update=0.0002, g_fix=-0.0001, g_update=0.0000
# [epoch 100, it 3100] g_loss = 1.0524, d_loss = 1.1091, reg=0.0602, d_fix=-0.0469, d_update=-0.0003, g_fix=-0.0001, g_update=0.0000
# [epoch 103, it 3200] g_loss = 1.4615, d_loss = 0.9805, reg=0.0667, d_fix=-0.0469, d_update=0.0011, g_fix=-0.0001, g_update=0.0000
# [epoch 106, it 3300] g_loss = 0.8500, d_loss = 0.8835, reg=0.0594, d_fix=-0.0469, d_update=0.0001, g_fix=-0.0001, g_update=0.0000
# [epoch 109, it 3400] g_loss = 1.0520, d_loss = 0.9763, reg=0.0606, d_fix=-0.0469, d_update=0.0007, g_fix=-0.0001, g_update=0.0000
# [epoch 112, it 3500] g_loss = 1.2185, d_loss = 0.9720, reg=0.0559, d_fix=-0.0469, d_update=0.0016, g_fix=-0.0001, g_update=0.0000
# [epoch 116, it 3600] g_loss = 1.0024, d_loss = 0.9709, reg=0.0642, d_fix=-0.0469, d_update=0.0019, g_fix=-0.0001, g_update=0.0000
# [epoch 119, it 3700] g_loss = 0.9187, d_loss = 0.8736, reg=0.0565, d_fix=-0.0469, d_update=0.0021, g_fix=-0.0001, g_update=0.0000
# [epoch 122, it 3800] g_loss = 0.7867, d_loss = 0.8985, reg=0.0546, d_fix=-0.0469, d_update=0.0023, g_fix=-0.0001, g_update=0.0000
# [epoch 125, it 3900] g_loss = 0.9031, d_loss = 0.8333, reg=0.0626, d_fix=-0.0469, d_update=0.0028, g_fix=-0.0001, g_update=0.0000
# [epoch 129, it 4000] g_loss = 1.2167, d_loss = 0.8624, reg=0.0646, d_fix=-0.0469, d_update=0.0026, g_fix=-0.0001, g_update=0.0000
# [epoch 132, it 4100] g_loss = 0.7190, d_loss = 0.9683, reg=0.0681, d_fix=-0.0469, d_update=0.0023, g_fix=-0.0001, g_update=0.0000
# [epoch 135, it 4200] g_loss = 0.8832, d_loss = 0.8915, reg=0.0753, d_fix=-0.0469, d_update=0.0014, g_fix=-0.0001, g_update=0.0000
# [epoch 138, it 4300] g_loss = 0.8940, d_loss = 0.8033, reg=0.0789, d_fix=-0.0469, d_update=0.0011, g_fix=-0.0001, g_update=0.0000
# [epoch 141, it 4400] g_loss = 1.6593, d_loss = 0.9999, reg=0.0680, d_fix=-0.0469, d_update=0.0013, g_fix=-0.0001, g_update=0.0000
# [epoch 145, it 4500] g_loss = 1.4596, d_loss = 0.8705, reg=0.0660, d_fix=-0.0469, d_update=0.0018, g_fix=-0.0001, g_update=0.0000
# [epoch 148, it 4600] g_loss = 1.5192, d_loss = 0.9409, reg=0.0803, d_fix=-0.0469, d_update=0.0020, g_fix=-0.0001, g_update=0.0000
# [epoch 151, it 4700] g_loss = 0.9911, d_loss = 0.8312, reg=0.0819, d_fix=-0.0469, d_update=0.0026, g_fix=-0.0001, g_update=0.0000
# [epoch 154, it 4800] g_loss = 0.9007, d_loss = 0.8011, reg=0.0721, d_fix=-0.0469, d_update=0.0023, g_fix=-0.0001, g_update=0.0000
# [epoch 158, it 4900] g_loss = 0.7648, d_loss = 0.8779, reg=0.0828, d_fix=-0.0469, d_update=0.0022, g_fix=-0.0001, g_update=0.0000
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /home/jovyan/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth
#   0%|          | 0.00/104M [00:00<?, ?B/s]
# /srv/conda/envs/saturn/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# /home/jovyan/git-repos/GANTransferLimitedData/gan_training/metrics/fid_score.py:72: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   batch = Variable(batch, volatile=True)
# /srv/conda/envs/saturn/lib/python3.9/site-packages/torch/nn/functional.py:3487: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# test it 4998: IS: mean 2.84, std 0.31, FID: mean 155.18, time: 16492.131200
# Saving backup...
# [epoch 161, it 5000] g_loss = 0.5843, d_loss = 1.0354, reg=0.0843, d_fix=-0.0469, d_update=0.0024, g_fix=-0.0001, g_update=0.0000
# [epoch 164, it 5100] g_loss = 1.2185, d_loss = 0.6726, reg=0.0812, d_fix=-0.0469, d_update=0.0026, g_fix=-0.0001, g_update=0.0000
# [epoch 167, it 5200] g_loss = 0.8090, d_loss = 0.8485, reg=0.0714, d_fix=-0.0469, d_update=0.0028, g_fix=-0.0001, g_update=0.0000
# [epoch 170, it 5300] g_loss = 1.2781, d_loss = 0.7067, reg=0.0801, d_fix=-0.0469, d_update=0.0030, g_fix=-0.0001, g_update=0.0000
# [epoch 174, it 5400] g_loss = 2.0784, d_loss = 0.9805, reg=0.0884, d_fix=-0.0469, d_update=0.0032, g_fix=-0.0001, g_update=0.0000
# [epoch 177, it 5500] g_loss = 1.0004, d_loss = 0.7080, reg=0.0693, d_fix=-0.0469, d_update=0.0032, g_fix=-0.0001, g_update=0.0000
# [epoch 180, it 5600] g_loss = 1.6311, d_loss = 0.7420, reg=0.0833, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 183, it 5700] g_loss = 0.7506, d_loss = 0.8915, reg=0.0836, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 187, it 5800] g_loss = 1.3461, d_loss = 0.8756, reg=0.0778, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 190, it 5900] g_loss = 1.0799, d_loss = 0.7202, reg=0.0832, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 193, it 6000] g_loss = 0.7933, d_loss = 0.7876, reg=0.0954, d_fix=-0.0469, d_update=0.0037, g_fix=-0.0001, g_update=0.0000
# [epoch 196, it 6100] g_loss = 1.0940, d_loss = 0.6401, reg=0.0874, d_fix=-0.0469, d_update=0.0038, g_fix=-0.0001, g_update=0.0000
# [epoch 200, it 6200] g_loss = 1.8854, d_loss = 0.7662, reg=0.0930, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 203, it 6300] g_loss = 0.9408, d_loss = 0.7534, reg=0.0885, d_fix=-0.0469, d_update=0.0038, g_fix=-0.0001, g_update=0.0000
# [epoch 206, it 6400] g_loss = 1.4355, d_loss = 0.6577, reg=0.0910, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 209, it 6500] g_loss = 0.8067, d_loss = 0.8007, reg=0.0843, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 212, it 6600] g_loss = 1.3795, d_loss = 0.7080, reg=0.0739, d_fix=-0.0469, d_update=0.0042, g_fix=-0.0001, g_update=0.0000
# [epoch 216, it 6700] g_loss = 1.6718, d_loss = 0.6217, reg=0.0929, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 219, it 6800] g_loss = 1.7102, d_loss = 0.8360, reg=0.0953, d_fix=-0.0469, d_update=0.0043, g_fix=-0.0001, g_update=0.0000
# [epoch 222, it 6900] g_loss = 1.5238, d_loss = 0.5599, reg=0.0771, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 225, it 7000] g_loss = 0.8484, d_loss = 0.7882, reg=0.0943, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 229, it 7100] g_loss = 0.9310, d_loss = 0.7177, reg=0.0790, d_fix=-0.0469, d_update=0.0042, g_fix=-0.0001, g_update=0.0000
# [epoch 232, it 7200] g_loss = 1.0104, d_loss = 0.6615, reg=0.0718, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 235, it 7300] g_loss = 1.0192, d_loss = 0.7033, reg=0.0943, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 238, it 7400] g_loss = 1.0983, d_loss = 0.7378, reg=0.0933, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 241, it 7500] g_loss = 1.1571, d_loss = 0.6758, reg=0.1017, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 245, it 7600] g_loss = 0.8610, d_loss = 0.7537, reg=0.0925, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 248, it 7700] g_loss = 1.8208, d_loss = 0.6453, reg=0.0977, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 251, it 7800] g_loss = 1.4037, d_loss = 0.5782, reg=0.0976, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 254, it 7900] g_loss = 1.3344, d_loss = 0.6788, reg=0.0906, d_fix=-0.0469, d_update=0.0042, g_fix=-0.0001, g_update=0.0000
# [epoch 258, it 8000] g_loss = 1.3799, d_loss = 0.6407, reg=0.0950, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 261, it 8100] g_loss = 1.3094, d_loss = 0.6807, reg=0.0929, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 264, it 8200] g_loss = 1.7454, d_loss = 0.5954, reg=0.1011, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 267, it 8300] g_loss = 1.3671, d_loss = 0.6089, reg=0.1020, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 270, it 8400] g_loss = 1.7335, d_loss = 0.6054, reg=0.0969, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 274, it 8500] g_loss = 1.6117, d_loss = 0.7066, reg=0.0987, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 277, it 8600] g_loss = 1.6407, d_loss = 0.5058, reg=0.1033, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 280, it 8700] g_loss = 2.2666, d_loss = 0.6588, reg=0.1030, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 283, it 8800] g_loss = 1.4037, d_loss = 0.5632, reg=0.0934, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 287, it 8900] g_loss = 1.8202, d_loss = 0.4833, reg=0.0966, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 290, it 9000] g_loss = 1.6804, d_loss = 0.6263, reg=0.0951, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 293, it 9100] g_loss = 1.6343, d_loss = 0.5869, reg=0.0960, d_fix=-0.0469, d_update=0.0037, g_fix=-0.0001, g_update=0.0000
# [epoch 296, it 9200] g_loss = 1.6480, d_loss = 0.5325, reg=0.0858, d_fix=-0.0469, d_update=0.0038, g_fix=-0.0001, g_update=0.0000
# [epoch 300, it 9300] g_loss = 1.3081, d_loss = 0.5663, reg=0.0806, d_fix=-0.0469, d_update=0.0037, g_fix=-0.0001, g_update=0.0000
# [epoch 303, it 9400] g_loss = 1.8323, d_loss = 0.6686, reg=0.0957, d_fix=-0.0469, d_update=0.0038, g_fix=-0.0001, g_update=0.0000
# [epoch 306, it 9500] g_loss = 1.0987, d_loss = 0.7155, reg=0.1037, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 309, it 9600] g_loss = 1.1843, d_loss = 0.5785, reg=0.0932, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 312, it 9700] g_loss = 1.4646, d_loss = 0.5082, reg=0.1009, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 316, it 9800] g_loss = 2.1231, d_loss = 0.6576, reg=0.0868, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 319, it 9900] g_loss = 1.2420, d_loss = 0.5657, reg=0.1068, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# test it 9998: IS: mean 2.69, std 0.28, FID: mean 144.51, time: 32968.199755
# Saving backup...
# Total= 27963332 Trainable= 23917057 fixed= 4046275
# [epoch 322, it 10000] g_loss = 1.3457, d_loss = 0.5726, reg=0.0928, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 325, it 10100] g_loss = 1.6826, d_loss = 0.5198, reg=0.1063, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 329, it 10200] g_loss = 1.1030, d_loss = 0.6052, reg=0.1130, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 332, it 10300] g_loss = 0.7586, d_loss = 0.7339, reg=0.1002, d_fix=-0.0469, d_update=0.0034, g_fix=-0.0001, g_update=0.0000
# [epoch 335, it 10400] g_loss = 0.9592, d_loss = 0.6838, reg=0.1196, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 338, it 10500] g_loss = 1.1271, d_loss = 0.6254, reg=0.1076, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 341, it 10600] g_loss = 1.5575, d_loss = 0.5331, reg=0.1025, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 345, it 10700] g_loss = 1.8296, d_loss = 0.4285, reg=0.1147, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 348, it 10800] g_loss = 0.9486, d_loss = 0.6087, reg=0.1146, d_fix=-0.0469, d_update=0.0034, g_fix=-0.0001, g_update=0.0000
# [epoch 351, it 10900] g_loss = 1.4066, d_loss = 0.6359, reg=0.1172, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 354, it 11000] g_loss = 1.4268, d_loss = 0.4555, reg=0.0996, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 358, it 11100] g_loss = 1.7287, d_loss = 0.6194, reg=0.0909, d_fix=-0.0469, d_update=0.0037, g_fix=-0.0001, g_update=0.0000
# [epoch 361, it 11200] g_loss = 1.7268, d_loss = 0.5171, reg=0.0961, d_fix=-0.0469, d_update=0.0037, g_fix=-0.0001, g_update=0.0000
# [epoch 364, it 11300] g_loss = 1.5116, d_loss = 0.4799, reg=0.1143, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 367, it 11400] g_loss = 1.5263, d_loss = 0.5419, reg=0.1104, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 370, it 11500] g_loss = 1.1775, d_loss = 0.5755, reg=0.1316, d_fix=-0.0469, d_update=0.0033, g_fix=-0.0001, g_update=0.0000
# [epoch 374, it 11600] g_loss = 1.6965, d_loss = 0.5113, reg=0.1052, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 377, it 11700] g_loss = 2.1935, d_loss = 0.5398, reg=0.0974, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 380, it 11800] g_loss = 1.1828, d_loss = 0.5697, reg=0.0927, d_fix=-0.0469, d_update=0.0034, g_fix=-0.0001, g_update=0.0000
# [epoch 383, it 11900] g_loss = 1.3697, d_loss = 0.5429, reg=0.0957, d_fix=-0.0469, d_update=0.0034, g_fix=-0.0001, g_update=0.0000
# [epoch 387, it 12000] g_loss = 2.0237, d_loss = 0.4603, reg=0.0970, d_fix=-0.0469, d_update=0.0032, g_fix=-0.0001, g_update=0.0000
# [epoch 390, it 12100] g_loss = 1.2197, d_loss = 0.5898, reg=0.1085, d_fix=-0.0469, d_update=0.0032, g_fix=-0.0001, g_update=0.0000
# [epoch 393, it 12200] g_loss = 1.8357, d_loss = 0.5077, reg=0.0975, d_fix=-0.0469, d_update=0.0033, g_fix=-0.0001, g_update=0.0000
# [epoch 396, it 12300] g_loss = 1.0729, d_loss = 0.5777, reg=0.0932, d_fix=-0.0469, d_update=0.0032, g_fix=-0.0001, g_update=0.0000
# [epoch 400, it 12400] g_loss = 2.0765, d_loss = 0.5437, reg=0.1148, d_fix=-0.0469, d_update=0.0033, g_fix=-0.0001, g_update=0.0000
# [epoch 403, it 12500] g_loss = 1.5979, d_loss = 0.7274, reg=0.1113, d_fix=-0.0469, d_update=0.0033, g_fix=-0.0001, g_update=0.0000
# [epoch 406, it 12600] g_loss = 1.4740, d_loss = 0.5257, reg=0.1136, d_fix=-0.0469, d_update=0.0033, g_fix=-0.0001, g_update=0.0000
# [epoch 409, it 12700] g_loss = 1.7300, d_loss = 0.5665, reg=0.1105, d_fix=-0.0469, d_update=0.0034, g_fix=-0.0001, g_update=0.0000
# [epoch 412, it 12800] g_loss = 1.8963, d_loss = 0.4665, reg=0.0894, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 416, it 12900] g_loss = 1.6521, d_loss = 0.4985, reg=0.1163, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 419, it 13000] g_loss = 1.6339, d_loss = 0.5045, reg=0.1126, d_fix=-0.0469, d_update=0.0036, g_fix=-0.0001, g_update=0.0000
# [epoch 422, it 13100] g_loss = 1.6457, d_loss = 0.6096, reg=0.1033, d_fix=-0.0469, d_update=0.0038, g_fix=-0.0001, g_update=0.0000
# [epoch 425, it 13200] g_loss = 1.8564, d_loss = 0.6197, reg=0.0957, d_fix=-0.0469, d_update=0.0038, g_fix=-0.0001, g_update=0.0000
# [epoch 429, it 13300] g_loss = 1.2567, d_loss = 0.5570, reg=0.0947, d_fix=-0.0469, d_update=0.0035, g_fix=-0.0001, g_update=0.0000
# [epoch 432, it 13400] g_loss = 1.7336, d_loss = 0.5613, reg=0.1080, d_fix=-0.0469, d_update=0.0038, g_fix=-0.0001, g_update=0.0000
# [epoch 435, it 13500] g_loss = 1.7382, d_loss = 0.5397, reg=0.1029, d_fix=-0.0469, d_update=0.0037, g_fix=-0.0001, g_update=0.0000
# [epoch 438, it 13600] g_loss = 1.9819, d_loss = 0.5029, reg=0.1149, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 441, it 13700] g_loss = 1.1317, d_loss = 0.5429, reg=0.1158, d_fix=-0.0469, d_update=0.0037, g_fix=-0.0001, g_update=0.0000
# [epoch 445, it 13800] g_loss = 1.9348, d_loss = 0.6242, reg=0.1005, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 448, it 13900] g_loss = 1.6956, d_loss = 0.4934, reg=0.1276, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 451, it 14000] g_loss = 2.2661, d_loss = 0.6479, reg=0.1080, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 454, it 14100] g_loss = 1.0982, d_loss = 0.6961, reg=0.0981, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 458, it 14200] g_loss = 1.9552, d_loss = 0.6513, reg=0.0992, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 461, it 14300] g_loss = 1.7079, d_loss = 0.5057, reg=0.0927, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 464, it 14400] g_loss = 1.4461, d_loss = 0.5084, reg=0.1022, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 467, it 14500] g_loss = 1.2043, d_loss = 0.6053, reg=0.1088, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 470, it 14600] g_loss = 1.4385, d_loss = 0.6345, reg=0.0946, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 474, it 14700] g_loss = 1.5830, d_loss = 0.6056, reg=0.1026, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 477, it 14800] g_loss = 1.8221, d_loss = 0.5910, reg=0.1148, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 480, it 14900] g_loss = 1.2251, d_loss = 0.4887, reg=0.1139, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# test it 14998: IS: mean 2.56, std 0.33, FID: mean 109.43, time: 50034.990139
# Saving backup...
# [epoch 483, it 15000] g_loss = 1.3788, d_loss = 0.5036, reg=0.1118, d_fix=-0.0469, d_update=0.0039, g_fix=-0.0001, g_update=0.0000
# [epoch 487, it 15100] g_loss = 1.6493, d_loss = 0.5300, reg=0.1118, d_fix=-0.0469, d_update=0.0040, g_fix=-0.0001, g_update=0.0000
# [epoch 490, it 15200] g_loss = 1.2098, d_loss = 0.5376, reg=0.1108, d_fix=-0.0469, d_update=0.0041, g_fix=-0.0001, g_update=0.0000
# [epoch 493, it 15300] g_loss = 1.8129, d_loss = 0.5170, reg=0.0916, d_fix=-0.0469, d_update=0.0043, g_fix=-0.0001, g_update=0.0000
# [epoch 496, it 15400] g_loss = 1.3037, d_loss = 0.5358, reg=0.1005, d_fix=-0.0469, d_update=0.0044, g_fix=-0.0001, g_update=0.0000

# %%
# !ls
# Out:
# 'CELEBA_[f]GmDn.py'	     gan_training
#  configs		     LICENSE
#  data			     pretrained_model
#  download_pretrainedGAN.py   README.md
#  F:			     textures_our_contral_kernel_25_v2_16z_10reg
# 'Flower_[h]our.py'	     TransferGANLimitedData_v4.pdf
#  Flowers25_our.py

# %%
fid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19271/3682325369.py in <module>
# ----> 1 fid
#
# NameError: name 'fid' is not defined
